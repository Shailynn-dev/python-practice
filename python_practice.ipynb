# %% [markdown]
# <a href="https://colab.research.google.com/github/Shailynn-dev/python-practice/blob/main/python_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code on this page is purely to practice and to  prepare for exams

# %%
num = 90
user_input = ""

while user_input != num:
  user_input = int(input("Enter a Number: "))
  if user_input > num:
    print("too high")
  elif user_input < num:
    print("number is too low")
  else:
    print("yay you got it right")
#does not run and needs a better detailing
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11408/1649165687.py in <cell line: 0>()
#       3
#       4 while user_input != num:
# ----> 5   user_input = int(input("Enter a Number: "))
#       6   if user_input > num:
#       7     print("too high")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
name= "shailynn"
print(name)
# Out:
# shailynn

# %%
num = 90
user_input = 0
tries = 0

while user_input != num:
    user_input = int(input("Guess the number: "))
    tries += 1

    if user_input > num:
        print("Too high")
    elif user_input < num:
        print("Too low")
    else:
        print("Correct!")

print("You guessed the number in", tries, "tries")
# Out:
# Guess the number: 98
# Too high
# Guess the number: 76
# Too low
# Guess the number: 0
# Too low
# Guess the number: 9
# Too low
# Guess the number: 90
# Correct!
# You guessed the number in 5 tries

# %%
password = "python123"
user_input = ""
tries = 0

while user_input != password:
  user_input = input("enter a Password: ")
  tries += 1

  if user_input != password :
    print("Wrong password")
  else:
    print("Access Granted")

print("you have used", tries, " attemmpts inorder to get access")
# Out:
# enter a Password: shailynn123
# Wrong password
# enter a Password: fsdfgdsg
# Wrong password
# enter a Password: sdddsdsds
# Wrong password
# enter a Password: sdsdsdsgrtrewwe345
# Wrong password
# enter a Password: python123
# Access Granted
# you have used 5  attemmpts inorder to get access

# %%
#lists
fruits = ["apple", "mango", "orange", "strawberry", "blueberry"]
print(fruits[4])

#python starts at 0 so if 1 is enter the second item will be printed out
# Out:
# blueberry

# %%
nums = [10, 20, 30]

# Calculate the total sum of the list once, before iterating
total_num = sum(nums)

for n in nums:
    # This block is correctly indented as part of the loop
    print(n + 5)

print(f"The total sum of all numbers in the list is: {total_num}")
# Out:
# 15
# 25
# 35
# The total sum of all numbers in the list is: 60

# %%
numbers = [5, 10, 15, 20]

# for n in numbers: if this is added the loop will continue
total_num = sum(numbers)

print("Total:", total_num)
# Out:
# Total: 50

# %%
numbers = [5, 10, 15, 20]

total_num = 0

for n in numbers:
    total_num += n

print("Total:", total_num)
# Out:
# Total: 50

# %% [markdown]
# Activities done in Class:

# %%
numbers = [3, 8, 2, 8, 5, 0, 11, 8, 6]

# %%
total = 0

for num in numbers:
    total = total + num
    print("Added:", num, "-> Total:", total)
# Out:
# Added: 3 -> Total: 3
# Added: 8 -> Total: 11
# Added: 2 -> Total: 13
# Added: 8 -> Total: 21
# Added: 5 -> Total: 26
# Added: 0 -> Total: 26
# Added: 11 -> Total: 37
# Added: 8 -> Total: 45
# Added: 6 -> Total: 51

# %%
#Challenge 1: Count even numbers

def challenge_1(num_list):
    count = 0
    for num in num_list:
        if num % 2 == 0:
            count = count + 1
    print(count)

challenge_1(numbers)
# Out:
# 6

# %%
passwordAttempt = ""
password = "python123"

while passwordAttempt != "python123":
  passwordAttempt = input("enter a password: ")
  print("Try again")
else:
  print("Access granted!!!")
# Out:
# enter a password: fghsdfgf
# Try again
# enter a password: ghdfgrty
# Try again
# enter a password: sdfdsgdaf
# Try again
# enter a password: afgsdfgser
# Try again
# enter a password: asdfgsdfg
# Try again
# enter a password: python123
# Try again
# Access granted!!!

# %%
# Challenge 4: Find the biggest number without max()
largest = numbers[0]
for num in numbers:
    if num > largest:
        largest = num
print(largest)
# Out:
# 11

# %%
# --- Challenge 5: FizzBuzz Twist ---
for i in range(1, 31):
    if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz

# %%
# --- Challenge 6 *: Count Vowels ---
word = input("Enter a word: ")
count = 0
for letter in word:
    if letter in "aeiou":
        count = count + 1
print(count)
# Out:
# Enter a word: basic
# 2

# %%
# --- Challenge 7: Check Sorted Order ---
is_sorted = "Yes"

for i in range(1, len(numbers)):
    if numbers[i] < numbers[i - 1]:
        is_sorted = "No"
        break
print(is_sorted)
# Out:
# No

# %%
# --- Challenge 8: Sum of Odd Numbers ---
total = 0
for num in numbers:
    if num % 2 != 0:
        total = total + num
print(total)
# Out:
# 19

# %%
# --- Challenge 9: Multiples in a List ---
n = 3  # Example multiple to look for
count = 0
for num in numbers:
    if num % n == 0:
        count = count + 1
print(count)
# Out:
# 3

# %%
# --- Challenge 10: Reverse Without Reverse ---
for i in range(len(numbers) - 1, -1, -1):
    print(numbers[i])
# Out:
# 6
# 8
# 11
# 0
# 5
# 8
# 2
# 8
# 3

# %%
# Setup data for Part 2
nums = [2, 4, 5, -1, -7, 9]
numbers = [3, 8, 2, 8, 5, 0, 11, 8, 6]

# %%
# --- Challenge 11: Shopping Total with Discount ---
prices = [20, 50, 40]  # Example list of prices
total = 0
for price in prices:
    total = total + price
if total > 100:
    total = total * 0.9
print(total)
# Out:
# 99.0

# %% [markdown]
# Questions designed by AI based off study guide

# %% [markdown]
#  # 1.Basic Input and Output

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Hello", name, "you are", age, "years old")
# Out:
# Enter your name: shailynn
# Enter your age: 19
# Hello shailynn you are 19 years old

# %% [markdown]
# # 2.Simple Calculation

# %%
item_price = int(input("Enter the price of the item: "))
item_Quantity = int(input("Enter the quantity of the item: "))
total_cost = 0

total_cost = item_price * item_Quantity

print("Total cost is: ", total_cost)
# Out:
# Enter the price of the item: 20
# Enter the quantity of the item: 7
# Total cost is:  140

# %% [markdown]
# # 3.Area of a Rectangle:

# %%
length = int(input("enter the length: "))
width = int(input("Enter the width: "))

area = length * width

print(area)
# Out:
# enter the length: 20
# Enter the width: 20
# 400

# %% [markdown]
# # 4.Even or Odd

# %%
user_num = int(input("Enter Any number: "))

output = user_num % 2

print(output)
# Correc answer
#username = input("enter the username: ")
#password = input("enter the password: ")

#if username == "admin" and password == "1234":
 # print("login successful")
 #else:
 # print("login invalid")
# Out:
# Enter Any number: 5
# 1

# %% [markdown]
# # 5.Pass or Fail

# %%
user_mark = int(input("enter your mark: "))

if user_mark < 50:
  print("you Failed")
else:
  print("you passed")
# Out:
# enter your mark: 79
# you passed

# %% [markdown]
#  # 6. Age Checker

# %%
user_age = int(input("enter your age: "))

if user_age < 18:
  print("Access Denied")
else:
  print("you may enter")
# Out:
# enter your age: 19
# you may enter

# %% [markdown]
# # 7. Grade Calculator

# %%
mark = int(input("enter the optained Mark: "))

if mark >= 90:
    print("A+")
elif 80 <= mark <= 89:
    print("A")
elif 70 <= mark <= 79:
    print("B")
elif 60 <= mark <= 69:
    print("C")
else:
    print("Failed")
# Out:
# enter the optained Mark: 67
# C

# %% [markdown]
# # 8. Temperature Checker

# %%
temp = int(input("enter the temperature: "))

if temp > 30:
  print("Its hot today")
elif 20 <= temp <= 30:
  print("Nice Weather")
else:
  print("its cold today")
# Out:
# enter the temperature: 32
# Its hot today

# %% [markdown]
# # 9. Login System

# %%
username = input("enter the username: ")
password = input("enter the password: ")

if username == "admin" and password == "1234":
  print("login successful")
else:
  print("login invalid")
# Out:
# enter the username: shailynn
# enter the password: 5655
# login invalid

# %% [markdown]
# # 10. Simple loan Qualification

# %%
salary = int(input("enter your salary"))
years_worked = int(input("enter years worked: "))

if salary < 30000 and years_worked < 2:
  print("Loan Denied")
else:
  print("Loan Granted")

  #salary = int(input("Enter your salary: "))
#years_worked = int(input("Enter years worked: "))

#if salary >= 30000 and years_worked >= 2:
  #  print("Loan Granted")
#else:
 #   print("Loan Denied")
# Out:
# enter your salary45000
# enter years worked: 5
# Loan Granted

# %% [markdown]
# # 11. String Comparison

# %%
user_input = input("Type Yes: ")

if user_input != "yes".upper():
  print("Cancelled")
else:
  print("Confirmed")

  #Corrected version:
  #user_input = input("Type YES: ")

#if user_input.upper() == "YES":
 #   print("Confirmed")
#else:
 #   print("Cancelled")

# %% [markdown]
# # 12. Circle Area

# %%
pi = 3.14
radius = int(input("enter the radius: "))

area = pi * radius ** 2

print(area)
# Out:
# enter the radius: 34
# 3629.84
